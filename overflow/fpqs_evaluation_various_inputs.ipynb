# %%
from overflow1_new import simulate_classical_circ as sim1
from overflow2 import simulate_classical_circ as sim2
from overflow3_new import simulate_classical_circ as sim3
from overflow4 import simulate_classical_circ as sim4

# %%
delta = 0.25

for i in range(1, 10): 
    sim1(n_shots=100, n_iter=i, plot=False)
# Out:
# 1
# {'0010': 3, '0100': 7, '0110': 11, '0111': 5, '0000': 5, '0001': 6, '0011': 2, '1000': 61}
# 2
# {'0000': 1, '0110': 1, '1000': 98}
# 3
# {'0100': 2, '0001': 1, '0000': 3, '0010': 1, '0110': 4, '0111': 1, '1000': 88}
# 4
# {'0010': 1, '0110': 8, '0100': 6, '0111': 3, '0000': 3, '0001': 6, '0011': 2, '1000': 71}
# 5
# {'0010': 1, '0110': 8, '0100': 5, '0111': 2, '0000': 4, '0011': 1, '0001': 4, '1000': 75}
# 6
# {'0000': 1, '0110': 1, '1000': 98}
# 7
# {'0100': 2, '0000': 3, '0010': 1, '0110': 3, '0111': 1, '1000': 90}
# 8
# {'0010': 1, '0110': 8, '0100': 6, '0111': 3, '0000': 3, '0001': 6, '0011': 2, '1000': 71}
# 9
# {'0010': 1, '0110': 8, '0100': 5, '0111': 2, '0000': 4, '0011': 1, '0001': 4, '1000': 75}

# %%
for i in range(1, 10): 
    sim2(n_shots=100, n_iter=i)
# Out:
# 1
# {'0101': 4, '0110': 5, '0100': 8, '0001': 5, '0010': 5, '0000': 5, '0011': 5, '0111': 63}
# 2
# {'0111': 100}
# 3
# {'0001': 1, '0010': 1, '0000': 1, '0011': 2, '0111': 95}
# 4
# {'0101': 3, '0001': 2, '0110': 4, '0100': 2, '0010': 5, '0000': 4, '0011': 4, '0111': 76}
# 5
# {'0101': 2, '0100': 1, '0001': 3, '0110': 4, '0010': 1, '0000': 2, '0011': 3, '0111': 84}
# 6
# {'0111': 100}
# 7
# {'0001': 1, '0000': 1, '0011': 1, '0111': 97}
# 8
# {'0101': 3, '0001': 2, '0110': 4, '0100': 2, '0010': 4, '0000': 4, '0011': 4, '0111': 77}
# 9
# {'0101': 2, '0100': 1, '0001': 3, '0110': 4, '0010': 3, '0000': 2, '0011': 3, '0111': 82}

# %%
for i in range(1, 10): 
    sim3(n_shots=100, n_iter=i)
# Out:
# 1
# {'0011': 2, '0101': 3, '1000': 62, '0111': 3, '0010': 3, '0000': 5, '0001': 6, '0110': 11, '0100': 5}
# 2
# {'0000': 1, '0110': 1, '1000': 98}
# 3
# {'0100': 1, '0101': 2, '0110': 4, '0000': 3, '0010': 1, '0111': 1, '1000': 87, '0001': 1}
# 4
# {'0011': 2, '0101': 2, '1000': 71, '0111': 2, '0000': 4, '0100': 4, '0110': 9, '0001': 5, '0010': 1}
# 5
# {'0001': 2, '0011': 1, '0111': 2, '0110': 8, '0000': 5, '1000': 77, '0101': 2, '0010': 1, '0100': 2}
# 6
# {'0000': 1, '0110': 1, '1000': 98}
# 7
# {'0100': 1, '0110': 3, '0101': 1, '0000': 3, '0010': 1, '0111': 1, '1000': 90}
# 8
# {'0011': 2, '0101': 2, '1000': 72, '0111': 2, '0000': 4, '0100': 4, '0110': 8, '0001': 5, '0010': 1}
# 9
# {'0011': 2, '0101': 2, '1000': 73, '0111': 2, '0000': 4, '0110': 8, '0001': 5, '0100': 3, '0010': 1}

# %%
for i in range(1, 10): 
    sim4(n_shots=100, n_iter=i)
# Out:
# 1
# {'0101': 2, '0110': 4, '1010': 24, '1001': 18, '1000': 33, '1011': 8, '0111': 11}
# 2
# {'0110': 3, '1010': 19, '1001': 22, '1000': 41, '0111': 4, '1011': 11}
# 3
# {'0101': 3, '1010': 19, '0110': 7, '1001': 19, '1000': 27, '1011': 7, '0111': 18}
# 4
# {'1010': 23, '1001': 22, '1000': 41, '1011': 14}
# 5
# {'0101': 3, '1010': 19, '0110': 6, '1001': 19, '1000': 26, '1011': 8, '0111': 19}
# 6
# {'0110': 3, '1010': 19, '1001': 22, '1000': 41, '0111': 2, '1011': 13}
# 7
# {'0101': 2, '0110': 4, '1010': 24, '1001': 18, '1000': 31, '1011': 7, '0111': 14}
# 8
# {'0101': 2, '0110': 4, '1010': 24, '1001': 18, '1000': 33, '1011': 8, '0111': 11}
# 9
# {'0101': 2, '0110': 4, '1010': 21, '1001': 18, '1000': 37, '1011': 11, '0111': 7}

# %%
for i in range(1, 10): 
    simMod(n_shots=100, n_iter=i)

# %%
for i in range(1, 10): 
    simMult(n_shots=100, n_iter=i)

# %%
for i in range(1, 7): 
    simDiv(n_shots=100, n_iter=i)
